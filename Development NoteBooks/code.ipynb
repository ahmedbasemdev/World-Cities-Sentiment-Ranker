# %% [markdown]
# {
#     "geotaggedNear": "Los Angeles",
#     "minimumReplies": 5,
#     "minimumRetweets": 5,
#     "onlyVerifiedUsers": true,
#     "withinRadius": "15km",
#     "query": "news",
#     "maxTweets": 50,
#     "searchMode": "recent"
# }

# %%
import requests
import os

# %%
import os
import requests

# Define the API endpoint
url = "https://api.apify.com/v2/acts/61RPP7dywgiy0JPD0/run-sync"

# Define the input parameters for the API
inputs = {
    "geotaggedNear": "Cairo, Egypt",
    "minimumFavorites": 100,
    "withinRadius": "30km",
    "minimumRetweets":50,
    "query": "news",
    "searchMode": "recent",
}

# Define the headers and parameters for the API request
params = {"token": os.environ['APIFY_TOKEN'], "maxItems": 12}

# Send the POST request to the API
response = requests.post(url, json=inputs, params=params)

# Check if the request was successful
if response.status_code == 201:
    data = response.json()  # Parse the JSON response
    print("Data retrieved successfully!")
    print(data)  # Print the data or handle it as needed
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
    print(response.text)  # Print the error message if available
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\Ahmed-Basem\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# c:\Users\Ahmed-Basem\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# c:\Users\Ahmed-Basem\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# c:\Users\Ahmed-Basem\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19492\2932953811.py in <module>
#      23 # Check if the request was successful
#      24 if response.status_code == 201:
# ---> 25     data = response.json()  # Parse the JSON response
#      26     print("Data retrieved successfully!")
#      27     print(data)  # Print the data or handle it as needed
#
# c:\Users\Ahmed-Basem\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     973             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#     977     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
data
# Out:
# []

# %%
url = f"https://api.apify.com/v2/actor-runs?token={os.environ['APIFY_TOKEN']}"

response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse the JSON response
    print("Data retrieved successfully!")
    print(data)  # Print the data or handle it as needed
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
    print(response.text)  # Print the error message if available
# Out:
# Data retrieved successfully!
# {'data': {'total': 12, 'count': 12, 'offset': 0, 'limit': 1000, 'desc': False, 'items': [{'id': 'fx2qGKfgqAzpj9v82', 'actId': '61RPP7dywgiy0JPD0', 'status': 'SUCCEEDED', 'startedAt': '2024-08-09T15:52:49.307Z', 'finishedAt': '2024-08-09T17:01:17.058Z', 'buildId': 'AU2ARh8DKXbvNqlIf', 'buildNumber': '0.0.375', 'meta': {'origin': 'API'}, 'defaultKeyValueStoreId': 'CXNqsTRko9dOg3CZb', 'defaultDatasetId': 'S7uhi1NR9TVbWjOAe', 'defaultRequestQueueId': 'HtdpVhwBjuIUZ9KYJ', 'usageTotalUsd': 0.25422984069713284}, {'id': 'hhfpbseM7x9teAieF', 'actId': '61RPP7dywgiy0JPD0', 'status': 'SUCCEEDED', 'startedAt': '2024-08-09T15:55:34.098Z', 'finishedAt': '2024-08-09T16:00:37.410Z', 'buildId': 'AU2ARh8DKXbvNqlIf', 'buildNumber': '0.0.375', 'meta': {'origin': 'API'}, 'defaultKeyValueStoreId': 'SNZjTEOSBOs2aF1Ic', 'defaultDatasetId': 'tZPAWa4DNL4YF8N75', 'defaultRequestQueueId': 'pxm3xJE0nkycbync3', 'usageTotalUsd': 0.02229149943253564}, {'id': 'T2o37iPJtvGuIvSIX', 'actId': '61RPP7dywgiy0JPD0', 'status': 'SUCCEEDED', 'startedAt': '2024-08-10T14:53:49.958Z', 'finishedAt': '2024-08-10T14:59:03.967Z', 'buildId': 'MSmGhuz5KCSZsYPkd', 'buildNumber': '0.0.377', 'meta': {'origin': 'API'}, 'defaultKeyValueStoreId': 'IXET5PjkwXpu35cog', 'defaultDatasetId': 'X4gEhneQgmFa8a1Xo', 'defaultRequestQueueId': 'yYsJUggsrrKFagvbg', 'usageTotalUsd': 0.021223880372466315}, {'id': 'wrcx4ZPLYpkVgAGiX', 'actId': '61RPP7dywgiy0JPD0', 'status': 'SUCCEEDED', 'startedAt': '2024-08-10T14:58:40.850Z', 'finishedAt': '2024-08-10T14:59:36.751Z', 'buildId': 'MSmGhuz5KCSZsYPkd', 'buildNumber': '0.0.377', 'meta': {'origin': 'API'}, 'defaultKeyValueStoreId': 'dUwHeShsXax3LGb0z', 'defaultDatasetId': 'TboNpVnr4FixmFgag', 'defaultRequestQueueId': '3SWtvwoyC1V1j7kxv', 'usageTotalUsd': 0.006661995611747105}, {'id': 'zv1fTNwtd0mdhTqte', 'actId': '61RPP7dywgiy0JPD0', 'status': 'SUCCEEDED', 'startedAt': '2024-08-10T15:04:20.424Z', 'finishedAt': '2024-08-10T17:11:17.022Z', 'buildId': 'MSmGhuz5KCSZsYPkd', 'buildNumber': '0.0.377', 'meta': {'origin': 'API'}, 'defaultKeyValueStoreId': 'HnCzChUMIBAi02weD', 'defaultDatasetId': 'OLvxpaPZw1H9cwl78', 'defaultRequestQueueId': 'BJCnJcxL55V3BzLNI', 'usageTotalUsd': 0.5240981477588514}, {'id': '5gS0idoaW6SdUMuI9', 'actId': '61RPP7dywgiy0JPD0', 'status': 'ABORTED', 'startedAt': '2024-08-10T18:28:51.071Z', 'finishedAt': '2024-08-10T18:29:20.607Z', 'buildId': 'MSmGhuz5KCSZsYPkd', 'buildNumber': '0.0.377', 'meta': {'origin': 'API'}, 'defaultKeyValueStoreId': 'D7gveeTw23FOF7L6u', 'defaultDatasetId': 'h1UWr5IOWfzenPxjI', 'defaultRequestQueueId': 'TgQY9Slo6iCLXwW08', 'usageTotalUsd': 0.0017761731586787436}, {'id': 'uh0awpJjGqcpe6ECa', 'actId': '61RPP7dywgiy0JPD0', 'status': 'SUCCEEDED', 'startedAt': '2024-08-11T12:05:49.793Z', 'finishedAt': '2024-08-11T12:05:55.740Z', 'buildId': '3klZKHHbyS80qlkKV', 'buildNumber': '0.0.378', 'meta': {'origin': 'API'}, 'defaultKeyValueStoreId': 'yAaxDcqsw4Od8iWia', 'defaultDatasetId': 'Y05LyKbbIql76TNAF', 'defaultRequestQueueId': '4zB2ETaYRNH860C3I', 'usageTotalUsd': 0.0002194852722005712}, {'id': '0bivrKeQvpDYEeqlf', 'actId': '61RPP7dywgiy0JPD0', 'status': 'SUCCEEDED', 'startedAt': '2024-08-11T12:06:21.032Z', 'finishedAt': '2024-08-11T12:06:30.408Z', 'buildId': '3klZKHHbyS80qlkKV', 'buildNumber': '0.0.378', 'meta': {'origin': 'API'}, 'defaultKeyValueStoreId': 'AcWUEmAcbsrk3uDlZ', 'defaultDatasetId': 'MXdUEgCbeVvh5Wfbw', 'defaultRequestQueueId': 'ohJhnfW7GnwJfssUp', 'usageTotalUsd': 0.0003138801891985867}, {'id': '5bwIhGIRcXPHmgOg4', 'actId': '61RPP7dywgiy0JPD0', 'status': 'SUCCEEDED', 'startedAt': '2024-08-11T12:14:32.648Z', 'finishedAt': '2024-08-11T12:14:41.800Z', 'buildId': '3klZKHHbyS80qlkKV', 'buildNumber': '0.0.378', 'meta': {'origin': 'API'}, 'defaultKeyValueStoreId': 'oIWkeIw4FiDRYbQbi', 'defaultDatasetId': 'iJOmdkCgHV7rkoQTz', 'defaultRequestQueueId': 'CZxNAhUFyvVKmsSSa', 'usageTotalUsd': 0.00030993014495737025}, {'id': 'XAtIHLmZi1BVRblIt', 'actId': '61RPP7dywgiy0JPD0', 'status': 'SUCCEEDED', 'startedAt': '2024-08-11 ...

# %%
data['data']['items'][-1]
# Out:
# {'id': 'RQakU7dn23GhQfi5Z',
#  'actId': '61RPP7dywgiy0JPD0',
#  'status': 'SUCCEEDED',
#  'startedAt': '2024-08-11T12:35:14.586Z',
#  'finishedAt': '2024-08-11T12:35:23.915Z',
#  'buildId': '3klZKHHbyS80qlkKV',
#  'buildNumber': '0.0.378',
#  'meta': {'origin': 'API'},
#  'defaultKeyValueStoreId': 'iUsSo2zlvXdkK4XHz',
#  'defaultDatasetId': 'KM1TNNgWMOvfLcakx',
#  'defaultRequestQueueId': 'xJy0Vd27gSwSpzprl',
#  'usageTotalUsd': 0.0003745997539460659}

# %%
import os
import requests

# Define the API endpoint
url = "https://api.apify.com/v2/datasets/KM1TNNgWMOvfLcakx/items?format=json"

# Set up the headers with the Bearer token
headers = {
    "Authorization": f"Bearer {os.environ['APIFY_TOKEN']}"
}

# Send the GET request to the API with the headers
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse the JSON response
    print("Data retrieved successfully!")
    print(data)  # Print the data or handle it as needed
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
    print(response.text)  # Print the error message if available
# Out:
# Data retrieved successfully!
# [{'type': 'tweet', 'id': '1822612307454623941', 'url': 'https://x.com/patrickzaki1/status/1822612307454623941', 'twitterUrl': 'https://twitter.com/patrickzaki1/status/1822612307454623941', 'text': '💙❤️🥇🥇🇮🇹🇮🇹', 'source': 'Twitter for iPhone', 'retweetCount': 0, 'replyCount': 0, 'likeCount': 8, 'quoteCount': 0, 'viewCount': 74, 'createdAt': 'Sun Aug 11 12:33:31 +0000 2024', 'lang': 'art', 'quoteId': '1822609437732778453', 'bookmarkCount': 0, 'isReply': False, 'author': {'type': 'user', 'userName': 'patrickzaki1', 'url': 'https://x.com/patrickzaki1', 'twitterUrl': 'https://twitter.com/patrickzaki1', 'id': '1468986387055751175', 'name': 'Patrickzaki', 'isVerified': False, 'profilePicture': 'https://pbs.twimg.com/profile_images/1589973711028887552/Wj0FDyZA_normal.jpg', 'coverPicture': 'https://pbs.twimg.com/profile_banners/1468986387055751175/1643054420', 'description': 'Human Rights Defender |\nMinority Rights Researcher |\nMA Gender Studies @unibo 🇮🇹 |\nFanatical Football Fan ⚽️', 'location': 'Cairo, Egypt', 'followers': 35282, 'following': 958, 'status': '', 'canDm': False, 'canMediaTag': True, 'createdAt': 'Thu Dec 09 16:50:47 +0000 2021', 'entities': {'description': {'urls': []}}, 'fastFollowersCount': 0, 'favouritesCount': 8721, 'hasCustomTimelines': True, 'isTranslator': False, 'mediaCount': 457, 'statusesCount': 3453, 'withheldInCountries': [], 'affiliatesHighlightedLabel': {}}, 'extendedEntities': {}, 'card': {}, 'place': {}, 'entities': {'hashtags': [], 'symbols': [], 'timestamps': [], 'urls': [], 'user_mentions': []}, 'isRetweet': False, 'isQuote': True, 'quote': {'type': 'tweet', 'id': '1822609437732778453', 'text': 'LES JEUX SONT FAITS 🥇🤩🤩🤩🤩🤩\n\n 💙 A PARIGI SI È SCRITTA LA STORIA: le azzurre di Velasco superano in finale gli Stati Uniti e conquistano il primo Oro Olimpico di sempre❗\n\n#LaNazionale | @Coninews | @ItaliaTeam_it | #Paris2024 https://t.co/I7JO8Qt9L5', 'source': 'Twitter Web App', 'retweetCount': 275, 'replyCount': 19, 'likeCount': 719, 'quoteCount': 26, 'viewCount': 8055, 'createdAt': 'Sun Aug 11 12:22:07 +0000 2024', 'lang': 'it', 'bookmarkCount': 5, 'author': {'type': 'user', 'userName': 'Federvolley', 'url': 'https://x.com/Federvolley', 'twitterUrl': 'https://twitter.com/Federvolley', 'id': '259696541', 'name': 'Federvolley ⭐️⭐️⭐️⭐️⭐️', 'isVerified': False, 'profilePicture': 'https://pbs.twimg.com/profile_images/1742477868284649472/cSIeuETX_normal.jpg', 'coverPicture': 'https://pbs.twimg.com/profile_banners/259696541/1712040201', 'description': 'Tutto il mondo del #Volley, #BeachVolley e #SittingVolley raccontato dalla Federazione Italiana Pallavolo (Fipav)', 'location': 'Roma', 'followers': 245778, 'following': 812, 'status': '', 'canDm': False, 'canMediaTag': True, 'createdAt': 'Wed Mar 02 12:10:48 +0000 2011', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'federvolley.it', 'expanded_url': 'http://www.federvolley.it', 'url': 'https://t.co/Fe5QRnW3wd', 'indices': [0, 23]}]}}, 'fastFollowersCount': 0, 'favouritesCount': 3957, 'hasCustomTimelines': False, 'isTranslator': False, 'mediaCount': 22967, 'statusesCount': 61681, 'withheldInCountries': [], 'affiliatesHighlightedLabel': {}}, 'extendedEntities': {'media': [{'display_url': 'pic.x.com/i7jo8qt9l5', 'expanded_url': 'https://twitter.com/Federvolley/status/1822609437732778453/photo/1', 'id_str': '1822609427993690112', 'indices': [224, 247], 'media_key': '3_1822609427993690112', 'media_url_https': 'https://pbs.twimg.com/media/GUs1nj_XgAAiyE5.jpg', 'type': 'photo', 'url': 'https://t.co/I7JO8Qt9L5', 'ext_media_availability': {'status': 'Available'}, 'features': {'large': {'faces': []}, 'medium': {'faces': []}, 'small': {'faces': []}, 'orig': {'faces': []}}, 'sizes': {'large': {'h': 838, 'w': 833, 'resize': 'fit'}, 'medium': {'h': 838, 'w': 833, 'resize': 'fit'}, 'small': {'h': 680, 'w': 676, 'resize': 'fit'}, 'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}}, 'original_info': {'height': 838, 'width': 833, 'focus_rects': [{'x':  ...

# %%
for i in range(10):
    print(    data[i]['text'])
# Out:
# 💙❤️🥇🥇🇮🇹🇮🇹
# فتوح مازال في التحقيق وغير صحيح ما يتم تداوله عن حـب.سه ٤ ايام على ذمة التحقيق
# انا ومين ؟
# https://t.co/XN24bC9FPB
# أنثُرُ كلماتي عطراً
#                        فوق صدري النّدي
# وأرُش حروفي لوناً
#                       كوجهي السًرمدي
#
# أمزج أنفاسي بزقزقة العصافير
# وأرسم أحلامي بريشة المقادير
#
# نادر
# @ work https://t.co/TNmOxwxRJn
# مساء الخير 💜
# 今更ダービーに勝てたところで評価は変わらんぞ？
# ( #･᷄ὢ･᷅ )
# @ItaliaTeam_it @Federvolley Congratulazioni dall'Egitto al popolo italiano. Viva il Paese della pizza 🏅🇮🇹💯
# حليمة عباس تنهي منافسات رفع الأثقال في المركز السابع برفع إجمالي 260 كجم 🏋️‍♀️
#
# #Olympics | #OlympicGames | #Paris2024 https://t.co/7R7Y1boRtA
